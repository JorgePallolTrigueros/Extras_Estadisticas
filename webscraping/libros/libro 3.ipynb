ano al final del camino [9587] (r1.2)','[ Gaiman, Neil  La joven durmiente y el huso [21746] (r1.1)','[Breve historia] [Pasajes 30] Vilches Fuentes, Gerardo  Breve historia del comic [31102] (r1.0)','[Cazadores de sombras 5]  Ciudad de las almas perdidas  Cassandra Clare','[Julius Bentheim 01] Ohri, Armin  La musa oscura [36610] (r2.2)','[krug book]  [f&sf]  Hearn Lafcadio  PERDERE LA FACCIA  [1988]','[Maestros de la Literatura Japonesa 03] Izumi, Kyoka  El santo del monte Koya y otros relatos [2831] (r1.1)','[Maestros de la Literatura Japonesa 14] Saikaku, Ihara  El gran espejo del amor entre hombres [30037] (r1.1)','[Misterios de Epoca 01] Braddon, Mary Elizabeth  El secreto de Aurora Floyd [27116] (r1.0)','[Misterios de Epoca 01] Braddon, Mary Elizabeth  El secreto de Aurora Floyd [27116] (r1.2)','[Misterios de Epoca 02] Green, Anna Katharine  El misterio de Gramercy Park [30687] (r1.0)','[Misterios de Epoca 03] Hume, Fergus  El misterio del carruaje [30598] (r1.1)','[Misterios de Epoca 03] Hume, Fergus  El misterio del carruaje [30598] (r1.1)','[Misterios de Epoca 04] Cauvain, Henry  Maximilien Heller [35599] (r1.0)','[Misterios de Epoca 05] Gaboriau, Emile  El crimen de Orcival [30532] (r1.4)','[Misterios de Epoca 06] Green, Anna Katharine  Uno de mis hijos [35562] (r1.0)','[Misterios de Epoca 06] Green, Anna Katharine  Uno de mis hijos [35562] (r1.1)','[Nacidos de la Bruma 02] El Pozo de la Ascension  Brandon Sanderson'];

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from time import sleep
import pymysql
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from time import sleep
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from time import sleep
import pymysql
import time 
from unidecode import unidecode


try:
    connection = pymysql.connect(host='localhost',user='root',password='Kojinanjo1@',db='pelis')
    print("Conectado correctamente")
except pymysql.Error as e:
    print("No puede conectar con MySQL %d: %s" %(e.args[0], e.args[1]))

cursor = connection.cursor()

print("CONTINUE")

df = pd.DataFrame()





url = "https://www.todostuslibros.com/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
s = Service('C:/chromedriver.exe')
driver = webdriver.Chrome(service=s)
driver.get(url)

#Lista_de_libros = ["asesino de brujas","Ataud cerrado","Botchan","Los Adivinos","Breve Historia del C\u00f3mic","Breve historia del Japon feudal - Ruben Almarza Gonzalez","Carlos Daniel Marchio - EL SALTO CUANTICO","Carrera De Harlan, La - Patricia Nell Warren","Cincuenta velas - Earl Derr Biggers","Cine japones - Nosferatu","Como explicar fisica cuantica con un gato zombi - Helena Gonzalez Buron","Como seducir a un hetero - Diego Manuel Bejar","Conelly, Michael - El quinto testigo","Crimen en la posada Arca de Noe - Molly Thynne","Crimenes sorprendentes de la historia argentina - Ricardo Canaletti","Damas Asesinas - Tori Telfer","Damas oscuras - AA VV","Dante La novela de su vida - Marco Santagata","Dante y su obra - Angel Crespo","De lo humano y lo divino - Javier Sanz","Del cabildo al shopping","Delta de Venus - Anais Nin","desktop","Diccionario de kanjis japoneses GUNKAN","Divina Comedia - Dante Alighieri","El angel blanco - Gemma Minguillon","El angel de la muerte - Steve Alten","El asesinato del Casino - S S Van Dine","El asesinato del Se\u00f1or Wickham - Claudia Gray","El candor de padre Brown - G K Chesterton","El Caso del Tarot - Pablo Poveda","El crisantemo y la espada  Patrones de la cultura japonesa - Ruth Fulton Benedict","El enigma de la habitacion 622 - Joel Dicker","El enigmatico Mr  Quin - Agatha Christie","El esoterismo de Dante - Rene Guenon","El imperio del vampiro - Jay Kristoff","El misterio de Chalk Hill - Susanne Goga","El misterio de Chalk Hill - Susanne Goga","El misterioso asesinato de Benson - S S Van Dine","El monasterio encantado - Robert van Gulik","El nino que dibujaba gatos - Lafcadio Hearn","El reino - Jo Nesbo","El secreto del conclave - Carlo A Martigli","El secreto del padre Brown - Gilbert Keith Chesterton","El tribunal de los pajaros - Agnes Ravatn","El viento conoce mi nombre - Isabel Allende","Ella quiere matarme - Javier Cosnava","En la mente de un gato - John Bradshaw","Eso no estaba en mi libro de historia de Cataluna - Javier Barraycoa","Eso no estaba en mi libro de Japon - Beatriz Lizana Lopez","Estados Unidos de Japon - Peter Tieryas","Fantasmagoria - Lewis Carroll","Fantasmas y samurais - Kid Okamoto","FELLOWES, Jessica -  - 1  Los cr\u00edmenes de Mitford","FELLOWES, Jessica -  - 2  Un cad\u00e1ver con clase","Fellowes, Jessica  - Los cr\u00edmenes de Mitford","Fellowes, Jessica  - Los cr\u00edmenes de Mitford","Fellowes, Jessica  - Un cad\u00e1ver con clase","Gaiman, Neil - El oceano al final del camino ","Gaiman, Neil - Humo y espejos","Gaiman, Neil - La joven durmiente y el huso","Gaiman, Neil - Neverwhere  "];
Lista_de_libros = ["Ataud cerrado"];
Libros_rechazados= list()
df = pd.DataFrame()


try:
    connection = pymysql.connect(host='localhost',user='root',password='Kojinanjo1@',db='pelis')
    print("Conectado correctamente")
except pymysql.Error as e:
    print("No puede conectar con MySQL %d: %s" %(e.args[0], e.args[1]))

titulolista = list()
imagenlista = list()
sinopsislista = list()
autorlista = list()

cursor = connection.cursor()



for libro in Lista_de_libros:
    
    driver.get(url)
    time.sleep(5)
    element=driver.find_element(By.ID,"main-search-input")
    element.send_keys(libro)
    element.send_keys(Keys.ENTER)  
    time.sleep(5)

    response = requests.get(driver.current_url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    try:
        enlaceUrlElem = soup.find("h2", attrs = {"class" : "title"}).find("a")
        enlaceUrl = enlaceUrlElem["href"]
        driver.get(enlaceUrl)
        time.sleep(5)
        response = requests.get(driver.current_url)
        soup = BeautifulSoup(response.text, "html.parser")
        time.sleep(5)
        libroEncontrado = False
        try:
            titulo = soup.find("h1", attrs = {"class" : "title"}).text.strip()
            print("TITULO")
            print(unidecode(titulo.lower()))
            print("LIBRO")
            print(unidecode(libro.lower()))
            if unidecode(titulo.lower()) == unidecode(libro.lower()):
                libroEncontrado = True
                titulolista.append(titulo)
                print("SI ha encontrado el libro y coincide el titulo")
            else:
                print("El titulo no coincide... tambien lo rechazamos")
                Libros_rechazados.append(libro)
        except:
            print("NO ha encontrado el libro") 

        print("Libro:")
        print(libro)
        if libroEncontrado:
            autor = soup.find("a", {"class": "author"}).text.strip()
            autorlista.append(autor)
            imagen = soup.find("img", attrs = {"class" : "portada"})["src"]
            imagenlista.append(imagen)
            sinopsis = ""
            try:
                sinopsis = soup.find("div", attrs = {"id" : "collapseSynopsis"}).find_all("p")[-1]
            except:
                sinopsis = soup.find("div", attrs = {"id" : "collapseSynopsis"}).text.strip()
            sinopsislista.append(sinopsis)    
        else:
            print("libro rechazado!!!")
            Libros_rechazados.append(libro)
        
    except:
        print("NO HA ENCONTRADO RESULTADOS PARA ESTE LIBRO") 
        Libros_rechazados.append(libro)
    
    
    
print("Datos Recogidos de Primer Elemento")

print(titulolista[0])
print(imagenlista[0])
print(sinopsislista[0])
print(autorlista[0]) 

print(len(titulolista))
print(len(imagenlista))
print(len(sinopsislista))
print(len(autorlista))

df["nombre"] = titulolista
df["imagen"] = imagenlista
df["descripcion"] = sinopsislista
df["autor"] = autorlista
    
sql = """INSERT INTO `pelis`.`libro` (`titulo`,`imagen`,`sinopsis`,`autor`) VALUES (%s, %s, %s, %s)"""

for ind in df.index:
    cursor.execute(sql, (df['nombre'][ind], df['imagen'][ind], df['descripcion'][ind], df['autor'][ind] ))
    connection.commit() 

df.head(2)
# Out:
# Conectado correctamente
# CONTINUE
# Conectado correctamente
# TITULO
# ataud cerrado
# LIBRO
# ataud cerrado
# SI ha encontrado el libro y coincide el titulo
# Libro:
# Ataud cerrado
# Datos Recogidos de Primer Elemento
# Ataúd cerrado
# https://static.cegal.es/imagenes/marcadas/9788467/978846705221.gif
# ...

# %%
---------------------------------------------------------------------------
ValueError                                Traceback (most recent call last)
Cell In[1], line 125
    123 df["nombre"] = titulolista
    124 df["imagen"] = imagenlista
--> 125 df["descripcion"] = sinopsislista
    126 df["autor"] = autorlista
    128 sql = """INSERT INTO `pelis`.`libros` (`nombre`,`imagen`,`descripcion`,`autor`) VALUES (%s, %s, %s, %s)"""

File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3980, in DataFrame.__setitem__(self, key, value)
   3977     self._setitem_array([key], value)
   3978 else:
   3979     # set column
-> 3980     self._set_item(key, value)

File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4174, in DataFrame._set_item(self, key, value)
   4164 def _set_item(self, key, value) -> None:
   4165     """
   4166     Add series to DataFrame in specified column.
   4167 
   (...)
   4172     ensure homogeneity.
   4173     """
-> 4174     value = self._sanitize_column(value)
   4176     if (
   4177         key in self.columns
   4178         and value.ndim == 1
   4179         and not is_extension_array_dtype(value)
   4180     ):
   4181         # broadcast across multiple columns if necessary
   4182         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):

File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4915, in DataFrame._sanitize_column(self, value)
   4912     return _reindex_for_setitem(Series(value), self.index)
   4914 if is_list_like(value):
-> 4915     com.require_length_match(value, self.index)
   4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)

File ~\anaconda3\Lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
    567 """
    568 Check the length of data matches the length of the index.
    569 """
    570 if len(data) != len(index):
--> 571     raise ValueError(
    572         "Length of values "
    573         f"({len(data)}) "
    574         "does not match length of index "
    575         f"({len(index)})"
    576     )

ValueError: Length of values (2) does not match length of index (3)

# %%
Lista_de_libros = ["asesino de brujas","Ataud cerrado","Botchan","Los Adivinos","Breve Historia del C\u00f3mic","Breve historia del Japon feudal - Ruben Almarza Gonzalez","Carlos Daniel Marchio - EL SALTO CUANTICO","Carrera De Harlan, La - Patricia Nell Warren","Cincuenta velas - Earl Derr Biggers","Cine japones - Nosferatu","Como explicar fisica cuantica con un gato zombi - Helena Gonzalez Buron","Como seducir a un hetero - Diego Manuel Bejar","Conelly, Michael - El quinto testigo","Crimen en la posada Arca de Noe - Molly Thynne","Crimenes sorprendentes de la historia argentina - Ricardo Canaletti","Damas Asesinas - Tori Telfer","Damas oscuras - AA VV","Dante La novela de su vida - Marco Santagata","Dante y su obra - Angel Crespo","De lo humano y lo divino - Javier Sanz","Del cabildo al shopping","Delta de Venus - Anais Nin","desktop","Diccionario de kanjis japoneses GUNKAN","Divina Comedia - Dante Alighieri","El angel blanco - Gemma Minguillon","El angel de la muerte - Steve Alten","El asesinato del Casino - S S Van Dine","El asesinato del Se\u00f1or Wickham - Claudia Gray","El candor de padre Brown - G K Chesterton"];

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from time import sleep
import pymysql
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from time import sleep
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from time import sleep
import pymysql
import time 


try:
    connection = pymysql.connect(host='localhost',user='root',password='Kojinanjo1@',db='pelis')
    print("Conectado correctamente")
except pymysql.Error as e:
    print("No puede conectar con MySQL %d: %s" %(e.args[0], e.args[1]))

cursor = connection.cursor()

print("CONTINUE")

df = pd.DataFrame()





url = "https://www.todostuslibros.com/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
s = Service('C:/chromedriver.exe')
driver = webdriver.Chrome(service=s)
driver.get(url)

Lista_de_libros = ['Hijos de la fabula','El peligro de estar cuerda'];
Libros_rechazados= list()
df = pd.DataFrame()


try:
    connection = pymysql.connect(host='localhost',user='root',password='Kojinanjo1@',db='pelis')
    print("Conectado correctamente")
except pymysql.Error as e:
    print("No puede conectar con MySQL %d: %s" %(e.args[0], e.args[1]))

titulolista = list()
imagenlista = list()
sinopsislista = list()
autorlista = list()

cursor = connection.cursor()



for url in Lista_de_libros:
    
    #print(url)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    
    titulo = soup.find("div", attrs = {"class" : "col-7 col-sm-12"}).find("h1").text.strip()
    titulolista.append(titulo)
    autor = soup.find("a", {"class": "author"}).text.strip()
    autorlista.append(autor)
    imagen = soup.find("img", attrs = {"class" : "portada"})
    imagenlista.append(imagen)   
    sinopsislista = soup.find("img", attrs = {"class" : "portada"})
    sinopsislista.append(sinopsislista)    
    
    
print("Datos Recogidos de Primer Elemento")

print(nombrelista[0])
print(imagenlista[0])
print(sinopsislistalista[0])
print(autorlista[0]) 

df["nombre"] = titulolista
df["imagen"] = imagenlista
df["descripcion"] = sinopsislista
df["autor"] = autorlista

    
sql = """INSERT INTO `pelis`.`libros` (`nombre`,`imagen`,`descripcion`,`autor`) VALUES (%s, %s, %s, %s)"""

for ind in df.index:
    cursor.execute(sql, (df['nombre'][ind], df['imagen'][ind], df['descripcion'][ind], df['autor'][ind] ))
    connection.commit() 

df.head(2)
